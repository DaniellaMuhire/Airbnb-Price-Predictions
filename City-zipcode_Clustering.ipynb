# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import math
# %matplotlib inline
import hvplot
import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
# Load the airbnblistingny.csv dataset.
file_path= "Resources/AirbnblistingNY.csv"
data = pd.read_csv(file_path, index_col = 0)
data.head()
# Out:
# /var/folders/lt/c6r0brd14djbk6h6mpz3cz0w0000gn/T/ipykernel_28252/3414537219.py:3: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, index_col = 0)
#                               listing_url       scrape_id last_scraped  \
# id
# 2539    https://www.airbnb.com/rooms/2539  20220907064715   2022-09-07
# 2595    https://www.airbnb.com/rooms/2595  20220907064715   2022-09-07
# 5121    https://www.airbnb.com/rooms/5121  20220907064715   2022-09-07
# 45910  https://www.airbnb.com/rooms/45910  20220907064715   2022-09-07
# 5136    https://www.airbnb.com/rooms/5136  20220907064715   2022-09-07
#
#             source                                      name  \
# id
# 2539   city scrape        Clean & quiet apt home by the park
# 2595   city scrape                     Skylit Midtown Castle
# 5121   city scrape                           BlissArtsSpace!
# 45910  city scrape        Beautiful Queens Brownstone! - 5BR
# 5136   city scrape  Spacious Brooklyn Duplex, Patio + Garden
#
#                                              description  \
# id
# 2539   Renovated apt home in elevator building.<br />...
# 2595   Beautiful, spacious skylit studio in the heart...
# 5121   One room available for rent in a 2 bedroom apt...
# 45910  <b>The space</b><br />Beautiful, fully furnish...
# 5136   We welcome you to stay in our lovely 2 br dupl...
#
#                                    neighborhood_overview  \
# id
# 2539     Close to Prospect Park and Historic Ditmas Park
# 2595   Centrally located in the heart of Manhattan ju...
# 5121                                                 NaN
# 45910                                                NaN
# 5136                                                 NaN
#
#                                              picture_url  host_id  \
# id
# 2539   https://a0.muscache.com/pictures/3949d073-a02e...     2787
# 2595   https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 5121   https://a0.muscache.com/pictures/2090980c-b68e...     7356
# 45910  https://a0.muscache.com/pictures/27117627/19ff...   204539
# 5136   https://a0.muscache.com/pictures/miso/Hosting-...     7378
#
#                                        host_url  ...  \
# id                                               ...
# 2539     https://www.airbnb.com/users/show/2787  ...
# 2595     https://www.airbnb.com/users/show/2845  ...
# 5121     https://www.airbnb.com/users/show/7356  ...
# 45910  https://www.airbnb.com/users/show/204539  ...
# 5136     https://www.airbnb.com/users/show/7378  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# id
# 2539                         5.00                   4.75                4.88
# 2595                         4.80                   4.81                4.40
# 5121                         4.91                   4.47                4.52
# 45910                        5.00                   4.82                4.55
# 5136                         5.00                   4.67                5.00
#
#       license instant_bookable calculated_host_listings_count  \
# id
# 2539      NaN                f                              9
# 2595      NaN                f                              3
# 5121      NaN                f                              2
# 45910     NaN                f                              6
# 5136      NaN                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# id
# 2539                                            1
# 2595                                            3
# 5121                                            0
# 45910                                           6
# 5136                                            1
#
#       calculated_host_listings_count_private_rooms  \
# id
# 2539                                             6
# 2595                                             0
# 5121                                             2
# 45910                                            0
# 5136                                             0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# id
# 2539                                            2              0.11
# 2595                                            0              0.31
# 5121                                            0              0.31
# 45910                                           0              0.10
# 5136                                            0              0.03
#
# [5 rows x 74 columns]

# %%
# remove NaN values from dataframe
data = data.dropna(how='any', subset=['zipcode', 'property_type', 'bedrooms', 'beds', 'bathrooms'])

# convert formatting for price
data['price'] = (data['price'].str.replace(r'[^-+\d.]', '').astype(float))

# drop any inconsistent values
data = data[data['accommodates'] != 0]
data = data[data['bedrooms'] != 0]
data = data[data['beds'] != 0]
data = data[data['price'] != 0.00]

# convert ZipCode
data['zipcode'] = data['zipcode'].str.replace(r'-\d+', '')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # remove NaN values from dataframe
# ----> 2 data = data.dropna(how='any', subset=['zipcode', 'property_type', 'bedrooms', 'beds', 'bathrooms'])
#       4 # convert formatting for price
#       5 data['price'] = (data['price'].str.replace(r'[^-+\d.]', '').astype(float))
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.9/site-packages/pandas/core/frame.py:6011, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6009     check = indices == -1
#    6010     if check.any():
# -> 6011         raise KeyError(np.array(subset)[check].tolist())
#    6012     agg_obj = self.take(indices, axis=agg_axis)
#    6014 if thresh is not None:
#
# KeyError: ['zipcode']

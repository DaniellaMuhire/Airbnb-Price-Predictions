# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import math
import pylab
import scipy.stats as stats
# %matplotlib inline

# %%
# Loading listing dataset
file_path = "Resources/listings_with_zips.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     id  host_id  host_listings_count  \
# 0           0             0   2539     2787                  9.0
# 1           1             1   2595     2845                  6.0
# 2           2             2   5121     7356                  2.0
# 3           3             3  45910   204539                  7.0
# 4           4             4   5136     7378                  1.0
#
#   neighbourhood_cleansed  latitude  longitude                property_type  \
# 0             Kensington  40.64529  -73.97238  Private room in rental unit
# 1                Midtown  40.75356  -73.98559           Entire rental unit
# 2     Bedford-Stuyvesant  40.68535  -73.95512  Private room in rental unit
# 3              Ridgewood  40.70309  -73.89963             Entire townhouse
# 4            Sunset Park  40.66265  -73.99454           Entire rental unit
#
#          room_type  accommodates  bedrooms  beds    price  minimum_nights  \
# ...

# %%
# Determine if there are any missing values in the data
df.count()
# Out:
# Unnamed: 0                39881
# Unnamed: 0.1              39881
# id                        39881
# host_id                   39881
# host_listings_count       39831
# neighbourhood_cleansed    39881
# latitude                  39881
# longitude                 39881
# property_type             39881
# room_type                 39881
# accommodates              39881
# bedrooms                  36098
# beds                      38997
# price                     39881
# minimum_nights            39881
# availability_30           39881
# number_of_reviews         39881
# review_scores_rating      31519
# zip                       39881
# dtype: int64

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Unnamed: 0 has 0 null values
# Column Unnamed: 0.1 has 0 null values
# Column id has 0 null values
# Column host_id has 0 null values
# Column host_listings_count has 50 null values
# Column neighbourhood_cleansed has 0 null values
# Column latitude has 0 null values
# Column longitude has 0 null values
# Column property_type has 0 null values
# Column room_type has 0 null values
# Column accommodates has 0 null values
# Column bedrooms has 3783 null values
# Column beds has 884 null values
# Column price has 0 null values
# Column minimum_nights has 0 null values
# Column availability_30 has 0 null values
# Column number_of_reviews has 0 null values
# Column review_scores_rating has 8362 null values
# Column zip has 0 null values

# %%
# Drop null rows
df = df.dropna()

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# Remove the Unanamed: 0 and  Unnamed: 0.1 Column
df.drop(columns=["Unnamed: 0"], inplace=True)
df.drop(columns=["Unnamed: 0.1"], inplace=True)

# %%
df.head()
# Out:
#       id  host_id  host_listings_count neighbourhood_cleansed  latitude  \
# 0   2539     2787                  9.0             Kensington  40.64529
# 2   5121     7356                  2.0     Bedford-Stuyvesant  40.68535
# 3  45910   204539                  7.0              Ridgewood  40.70309
# 4   5136     7378                  1.0            Sunset Park  40.66265
# 6  77765   417504                 30.0             Greenpoint  40.73777
#
#    longitude                property_type        room_type  accommodates  \
# 0  -73.97238  Private room in rental unit     Private room             2
# 2  -73.95512  Private room in rental unit     Private room             2
# 3  -73.89963             Entire townhouse  Entire home/apt            16
# 4  -73.99454           Entire rental unit  Entire home/apt             4
# 6  -73.95366       Room in boutique hotel       Hotel room             2
#
#    bedrooms  beds    price  minimum_nights  availability_30  \
# ...

# %%
# Fill in the empty rows with "0"
df=df.fillna(0)
df
# Out:
#              id    host_id  host_listings_count neighbourhood_cleansed  \
# 0          2539       2787                  9.0             Kensington
# 2          5121       7356                  2.0     Bedford-Stuyvesant
# 3         45910     204539                  7.0              Ridgewood
# 4          5136       7378                  1.0            Sunset Park
# 6         77765     417504                 30.0             Greenpoint
# ...         ...        ...                  ...                    ...
# 39871  38361585  290452185                  1.0        Cambria Heights
# 39873  42971489   40898359                  5.0           West Village
# 39876  43728504   23049030                  5.0          Rockaway Park
# 39877  44578886   48009648                  1.0        Upper West Side
# 39878  46355090  371552251                  1.0              Bellerose
#
#         latitude  longitude                property_type        room_type  \
# ...

# %%
# Determine data types for the DataFrame.
df.dtypes
# Out:
# id                          int64
# host_id                     int64
# host_listings_count       float64
# neighbourhood_cleansed     object
# latitude                  float64
# longitude                 float64
# property_type              object
# room_type                  object
# accommodates                int64
# bedrooms                  float64
# beds                      float64
# price                      object
# minimum_nights              int64
# availability_30             int64
# number_of_reviews           int64
# review_scores_rating      float64
# zip                         int64
# dtype: object

# %%
target= []

# %%
# Saving cleaned data
file_path = "Resources/listings_data_cleaned.csv"
df.to_csv(file_path, index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import math
import pylab
import scipy.stats as stats
# %matplotlib inline

# %%
cols = [
    'id',
    'host_id',
    'latitude',
    'longitude',
    'property_type',
    'room_type',
    'accommodates',
    'bedrooms',
    'beds',
    'price',
    'number_of_reviews',
    'review_scores_rating',
    'host_listings_count',
    'availability_30',
    'minimum_nights',
]

data_df= pd.read_csv("../Team_5-Airbnb/NYC_listings.csv.csv", usecols=cols)
data_df.head(20)
# Out:
#        id  host_id  host_listings_count  latitude  longitude  \
# 0    2539     2787                  9.0  40.64529  -73.97238
# 1    2595     2845                  6.0  40.75356  -73.98559
# 2    5121     7356                  2.0  40.68535  -73.95512
# 3   45910   204539                  7.0  40.70309  -73.89963
# 4    5136     7378                  1.0  40.66265  -73.99454
# 5   45935   204586                  1.0  40.80635  -73.92201
# 6   77765   417504                 30.0  40.73777  -73.95366
# 7    5178     8967                  1.0  40.76457  -73.98317
# 8   80493   434987                  1.0  40.72322  -73.98615
# 9   80684   417504                 30.0  40.73756  -73.95350
# 10  80700   417504                 30.0  40.73777  -73.95366
# 11  45936   867225                  1.0  40.80630  -73.95985
# 12   5203     7490                  1.0  40.80380  -73.96751
# 13   5803     9744                  3.0  40.66801  -73.98784
# 14  46911   210746                  3.0  40.68022  -73.97457
# 15  49048    35935                  5.0  40.68290  -73.95701
# 16  80924   438133                  2.0  40.67407  -73.98105
# 17   6848    15991                  1.0  40.70935  -73.95342
# 18  81739   417504                 30.0  40.73777  -73.95366
# 19  50447     9744                  3.0  40.66913  -73.99041
#
#                         property_type        room_type  accommodates  \
# 0         Private room in rental unit     Private room             2
# 1                  Entire rental unit  Entire home/apt             1
# 2         Private room in rental unit     Private room             2
# 3                    Entire townhouse  Entire home/apt            16
# 4                  Entire rental unit  Entire home/apt             4
# 5         Private room in rental unit     Private room             1
# 6              Room in boutique hotel       Hotel room             2
# 7         Private room in rental unit     Private room             2
# 8         Private room in rental unit     Private room             2
# 9              Room in boutique hotel       Hotel room             4
# 10             Room in boutique hotel     Private room             4
# 11  Private room in bed and breakfast     Private room             2
# 12        Private room in rental unit     Private room             1
# 13          Private room in townhouse     Private room             2
# 14               Private room in home     Private room             2
# 15               Private room in home     Private room             3
# 16                   Entire townhouse  Entire home/apt             5
# 17                 Entire rental unit  Entire home/apt             3
# 18             Room in boutique hotel     Private room             4
# 19                 Entire rental unit  Entire home/apt             4
#
#     bedrooms  beds    price  minimum_nights  availability_30  \
# 0        1.0   1.0  $299.00              30               21
# 1        NaN   1.0  $175.00              30                0
# 2        1.0   1.0   $60.00              30                5
# 3        5.0  10.0  $425.00              30               30
# 4        2.0   2.0  $275.00              21                0
# 5        1.0   1.0   $60.00              30               23
# 6        1.0   1.0  $308.00               2               15
# 7        1.0   1.0   $68.00               2                2
# 8        1.0   2.0   $55.00               2                0
# 9        1.0   2.0  $529.00               2               25
# 10       1.0   2.0  $372.00               2               17
# 11       1.0   1.0   $75.00              31                0
# 12       1.0   1.0   $75.00               2                0
# 13       1.0   1.0  $118.00               4                0
# 14       1.0   1.0  $123.00               3                0
# 15       1.0   2.0   $90.00              30                0
# 16       3.0   5.0  $160.00              30                0
# 17       NaN   1.0   $84.00              30                5
# 18       1.0   2.0  $372.00               2               17
# 19       1.0   2.0  $158.00               5                1
#
#     number_of_reviews  review_scores_rating
# 0                   9                  4.89
# 1                  49                  4.68
# 2                  50                  4.52
# 3                  13                  4.42
# 4                   3                  5.00
# 5                   0                   NaN
# 6                  42                  4.90
# 7                 550                  4.23
# 8                 207                  4.34
# 9                  10                  5.00
# 10                  9                  4.67
# 11                135                  4.65
# 12                118                  4.91
# 13                216                  4.70
# 14                 65                  4.69
# 15                 23                  4.36
# 16                 37                  4.86
# 17                185                  4.56
# 18                  2                  4.00
# 19                223                  4.83

# %%
# Determine if there are any missing values in the data
data_df.count()
# Out:
# id                      39881
# host_id                 39881
# host_listings_count     39831
# latitude                39881
# longitude               39881
# property_type           39881
# room_type               39881
# accommodates            39881
# bedrooms                36098
# beds                    38997
# price                   39881
# minimum_nights          39881
# availability_30         39881
# number_of_reviews       39881
# review_scores_rating    31519
# dtype: int64

# %%
# Determine if there are any missing values in the data
data_df.isnull().sum()
# Out:
# id                         0
# host_id                    0
# host_listings_count       50
# latitude                   0
# longitude                  0
# property_type              0
# room_type                  0
# accommodates               0
# bedrooms                3783
# beds                     884
# price                      0
# minimum_nights             0
# availability_30            0
# number_of_reviews          0
# review_scores_rating    8362
# dtype: int64

# %%
# Drop the NaNs
data_df.dropna()
# Out:
#              id    host_id  host_listings_count   latitude  longitude  \
# 0          2539       2787                  9.0  40.645290 -73.972380
# 2          5121       7356                  2.0  40.685350 -73.955120
# 3         45910     204539                  7.0  40.703090 -73.899630
# 4          5136       7378                  1.0  40.662650 -73.994540
# 6         77765     417504                 30.0  40.737770 -73.953660
# ...         ...        ...                  ...        ...        ...
# 39871  38361585  290452185                  1.0  40.702410 -73.724930
# 39873  42971489   40898359                  5.0  40.739967 -74.031677
# 39876  43728504   23049030                  5.0  40.581060 -73.829850
# 39877  44578886   48009648                  1.0  40.784590 -74.012530
# 39878  46355090  371552251                  1.0  40.723410 -73.722350
#
#                      property_type        room_type  accommodates  bedrooms  \
# 0      Private room in rental unit     Private room             2       1.0
# 2      Private room in rental unit     Private room             2       1.0
# 3                 Entire townhouse  Entire home/apt            16       5.0
# 4               Entire rental unit  Entire home/apt             4       2.0
# 6           Room in boutique hotel       Hotel room             2       1.0
# ...                            ...              ...           ...       ...
# 39871  Private room in guest suite     Private room             2       2.0
# 39873  Private room in rental unit     Private room             6       2.0
# 39876                  Entire home  Entire home/apt             2       1.0
# 39877           Entire rental unit  Entire home/apt             4       1.0
# 39878           Entire rental unit  Entire home/apt             2       1.0
#
#        beds    price  minimum_nights  availability_30  number_of_reviews  \
# 0       1.0  $299.00              30               21                  9
# 2       1.0   $60.00              30                5                 50
# 3      10.0  $425.00              30               30                 13
# 4       2.0  $275.00              21                0                  3
# 6       1.0  $308.00               2               15                 42
# ...     ...      ...             ...              ...                ...
# 39871   3.0  $125.00              27                3                  6
# 39873   2.0  $150.00               1                0                  3
# 39876   1.0  $157.00               3                0                 33
# 39877   2.0  $108.00               3                0                 52
# 39878   2.0  $140.00               3                0                 11
#
#        review_scores_rating
# 0                      4.89
# 2                      4.52
# 3                      4.42
# 4                      5.00
# 6                      4.90
# ...                     ...
# 39871                  5.00
# 39873                  5.00
# 39876                  4.91
# 39877                  4.79
# 39878                  4.45
#
# [28010 rows x 15 columns]

# %%
# Fill in the empty rows with "0"
data_df.fillna(0)
# Out:
#                        id    host_id  host_listings_count   latitude  \
# 0                    2539       2787                  9.0  40.645290
# 1                    2595       2845                  6.0  40.753560
# 2                    5121       7356                  2.0  40.685350
# 3                   45910     204539                  7.0  40.703090
# 4                    5136       7378                  1.0  40.662650
# ...                   ...        ...                  ...        ...
# 39876            43728504   23049030                  5.0  40.581060
# 39877            44578886   48009648                  1.0  40.784590
# 39878            46355090  371552251                  1.0  40.723410
# 39879  698195550745703156  151487807                  1.0  40.709192
# 39880            48971505      46201                  3.0  40.718350
#
#        longitude                property_type        room_type  accommodates  \
# 0     -73.972380  Private room in rental unit     Private room             2
# 1     -73.985590           Entire rental unit  Entire home/apt             1
# 2     -73.955120  Private room in rental unit     Private room             2
# 3     -73.899630             Entire townhouse  Entire home/apt            16
# 4     -73.994540           Entire rental unit  Entire home/apt             4
# ...          ...                          ...              ...           ...
# 39876 -73.829850                  Entire home  Entire home/apt             2
# 39877 -74.012530           Entire rental unit  Entire home/apt             4
# 39878 -73.722350           Entire rental unit  Entire home/apt             2
# 39879 -73.970121           Entire rental unit  Entire home/apt             4
# 39880 -74.044160  Private room in rental unit     Private room             1
#
#        bedrooms  beds    price  minimum_nights  availability_30  \
# 0           1.0   1.0  $299.00              30               21
# 1           0.0   1.0  $175.00              30                0
# 2           1.0   1.0   $60.00              30                5
# 3           5.0  10.0  $425.00              30               30
# 4           2.0   2.0  $275.00              21                0
# ...         ...   ...      ...             ...              ...
# 39876       1.0   1.0  $157.00               3                0
# 39877       1.0   2.0  $108.00               3                0
# 39878       1.0   2.0  $140.00               3                0
# 39879       2.0   2.0  $400.00              30                0
# 39880       1.0   0.0   $40.00               1                0
#
#        number_of_reviews  review_scores_rating
# 0                      9                  4.89
# 1                     49                  4.68
# 2                     50                  4.52
# 3                     13                  4.42
# 4                      3                  5.00
# ...                  ...                   ...
# 39876                 33                  4.91
# 39877                 52                  4.79
# 39878                 11                  4.45
# 39879                  0                  0.00
# 39880                 15                  4.47
#
# [39881 rows x 15 columns]

# %%
# Determine data types for the Airbnb DataFrame.
data_df.dtypes
# Out:
# id                        int64
# host_id                   int64
# host_listings_count     float64
# latitude                float64
# longitude               float64
# property_type            object
# room_type                object
# accommodates              int64
# bedrooms                float64
# beds                    float64
# price                    object
# minimum_nights            int64
# availability_30           int64
# number_of_reviews         int64
# review_scores_rating    float64
# dtype: object
